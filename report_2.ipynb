# %%
import pandas as pd
from settings import OUTPUT_PATH

# %%
wordnet_results = pd.read_csv(f"{OUTPUT_PATH}/wordnet_results.csv", index_col=0)
embeddings_results = pd.read_csv(f"{OUTPUT_PATH}/embeddings_results.csv", index_col=0)

# %%
wordnet_results.sort_values(by="similarity_cor", ascending=False)
# Out:
#              metric  similarity_func  similarity_cor  relatedness_cor  \
# 0   scikit.pearsonr  LeacockChodorow        0.580708         0.422920
# 0  scikit.spearmanr  LeacockChodorow        0.568200         0.431220
# 0  scikit.spearmanr         WuPalmer        0.188656         0.067516
# 0   scikit.pearsonr         WuPalmer        0.186899         0.073817
#
#                                         model_name  missed_words  \
# 0  slowosiec-graph-hiperonim-connected-by-top-sort            23
# 0  slowosiec-graph-hiperonim-connected-by-top-sort            23
# 0  slowosiec-graph-hiperonim-connected-by-top-sort            23
# 0  slowosiec-graph-hiperonim-connected-by-top-sort            23
#
#    unique_missed_words
# 0                   17
# 0                   17
# 0                   17
# 0                   17

# %%
embeddings_results.sort_values(by="similarity_cor", ascending=False)
# Out:
#               metric similarity_func  similarity_cor  relatedness_cor  \
# 9   scikit.spearmanr          cosine        0.401046         0.346237
# 7   scikit.spearmanr       manhattan        0.331307         0.250057
# 8    scikit.pearsonr          cosine        0.330242         0.309109
# 11  scikit.spearmanr       euclidean        0.329818         0.251002
# 10   scikit.pearsonr       euclidean        0.305692         0.268932
# 6    scikit.pearsonr       manhattan        0.304682         0.267452
# 3   scikit.spearmanr          cosine        0.268657         0.186608
# 5   scikit.spearmanr       euclidean        0.243265         0.263583
# 1   scikit.spearmanr       manhattan        0.242846         0.262367
# 2    scikit.pearsonr          cosine        0.239199         0.219135
# 4    scikit.pearsonr       euclidean        0.235099         0.283236
# 0    scikit.pearsonr       manhattan        0.232990         0.280217
#
#                                            model_name  \
# 9   fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 7   fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 8   fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 11  fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 10  fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 6   fasttext-kgr10.plain.lemma.lower.cbow.dim100.n...
# 3   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
# 5   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
# 1   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
# 2   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
# 4   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
# 0   w2v-nkjp+wiki-forms-restricted-100-cbow-hs.txt...
#
#                                    missed_words_array  missed_words  \
# 9   {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 7   {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 8   {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 11  {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 10  {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 6   {'mężczyźni', 'meble', 'Biblia', 'pieniądze', ...            15
# 3                                               set()             0
# 5                                               set()             0
# 1                                               set()             0
# 2                                               set()             0
# 4                                               set()             0
# 0                                               set()             0
#
#     unique_missed_words
# 9                     9
# 7                     9
# 8                     9
# 11                    9
# 10                    9
# 6                     9
# 3                     0
# 5                     0
# 1                     0
# 2                     0
# 4                     0
# 0                     0
